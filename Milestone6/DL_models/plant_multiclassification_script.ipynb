# %%
pip install fastai
# Out:
# Requirement already satisfied: fastai in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (2.7.12)
# Requirement already satisfied: pip in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (23.2.1)
# Requirement already satisfied: packaging in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (23.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (1.5.29)
# Requirement already satisfied: torchvision>=0.8.2 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (0.15.2)
# Requirement already satisfied: matplotlib in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (3.8.0)
# Requirement already satisfied: pandas in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (2.1.1)
# Requirement already satisfied: requests in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (2.31.0)
# Requirement already satisfied: pyyaml in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>6.0.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (9.4.0)
# Requirement already satisfied: scikit-learn in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (1.2.2)
# Requirement already satisfied: scipy in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (1.11.3)
# Requirement already satisfied: spacy<4 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (3.5.3)
# Requirement already satisfied: torch<2.1,>=1.7 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from fastai) (2.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (3.0.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (0.4.2)
# Requirement already satisfied: pathy>=0.10.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (1.26.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (1.10.12)
# Requirement already satisfied: jinja2 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (3.1.2)
# Requirement already satisfied: setuptools in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (68.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from requests->fastai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from requests->fastai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from requests->fastai) (2023.7.22)
# Requirement already satisfied: filelock in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from torch<2.1,>=1.7->fastai) (3.12.4)
# Requirement already satisfied: typing-extensions in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from torch<2.1,>=1.7->fastai) (4.7.1)
# Requirement already satisfied: sympy in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from torch<2.1,>=1.7->fastai) (1.12)
# Requirement already satisfied: networkx in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from torch<2.1,>=1.7->fastai) (3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from matplotlib->fastai) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from matplotlib->fastai) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from matplotlib->fastai) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from matplotlib->fastai) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from pandas->fastai) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from pandas->fastai) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from scikit-learn->fastai) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from scikit-learn->fastai) (3.2.0)
# Requirement already satisfied: six>=1.5 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from jinja2->spacy<4->fastai) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages (from sympy->torch<2.1,>=1.7->fastai) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastai.vision.all import *
from fastai import *
from pathlib import Path
import pandas as pd

# %%
torch.cuda.set_device(7)

# %%
import zipfile

# Specify the path to the zip file
zip_file_path = '/raid10/active_users/groupA/ml/data.zip'

# Specify the directory where you want to extract the contents
extracted_dir = '/raid10/active_users/groupA/ml'

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents to the specified directory
    zip_ref.extractall(extracted_dir)

# %%
train_data = Path('/raid10/active_users/groupA/ml/train')
test_data = Path('/raid10/active_users/groupA/ml/test')

# %%
train_fns = get_image_files(train_data)
train_fns

test_fns = get_image_files(test_data)
test_fns
# Out:
# (#794) [Path('/raid10/active_users/groupA/ml/test/d7017f701.png'),Path('/raid10/active_users/groupA/ml/test/6680836dd.png'),Path('/raid10/active_users/groupA/ml/test/a0b393945.png'),Path('/raid10/active_users/groupA/ml/test/e783f5a4f.png'),Path('/raid10/active_users/groupA/ml/test/d93c7ab6d.png'),Path('/raid10/active_users/groupA/ml/test/df7cb5f87.png'),Path('/raid10/active_users/groupA/ml/test/24c94a6ca.png'),Path('/raid10/active_users/groupA/ml/test/444473900.png'),Path('/raid10/active_users/groupA/ml/test/9baf94467.png'),Path('/raid10/active_users/groupA/ml/test/3f92d8039.png')...]

# %%
plant = DataBlock(blocks=(ImageBlock , CategoryBlock) ,
                   get_items=get_image_files,
                   get_y = parent_label,
                   item_tfms = RandomResizedCrop(460, min_scale=0.75),
                   batch_tfms = [*aug_transforms(size=224, max_warp=0, max_zoom= 0.8), Normalize.from_stats(*imagenet_stats)])

train_dls = plant.dataloaders(train_data, bs=64)
train_dls.show_batch()
# Out:
# /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages/fastai/data/transforms.py:225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(col):

# %%
print(train_dls.vocab)
len(train_dls.vocab)
# Out:
# ['Black-grass', 'Charlock', 'Cleavers', 'Common Chickweed', 'Common wheat', 'Fat Hen', 'Loose Silky-bent', 'Maize', 'Scentless Mayweed', 'Shepherds Purse', 'Small-flowered Cranesbill', 'Sugar beet']
# 12

# %%
# Getting the Metrics for evaluation

f1_score = F1Score(average='micro')
precision = Precision(average='micro')
recall = Recall(average='micro')

# %%
learn = cnn_learner(train_dls, resnet50, pretrained=True, metrics=[error_rate ,f1_score, precision, recall ,accuracy]).to_fp16()
# Out:
# /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages/fastai/vision/learner.py:288: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /raid10/active_users/groupA/miniconda/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): fastai.layers.Flatten(full=False)
#     (2): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=4096, out_features=512, bias=False)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=12, bias=False)
#   )
# )

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0008317637839354575)

# %%
learn.fit_one_cycle(4, 0.0008317637839354575)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.917874</td>
#       <td>0.599684</td>
#       <td>0.194737</td>
#       <td>0.805263</td>
#       <td>0.805263</td>
#       <td>0.805263</td>
#       <td>0.805263</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.923814</td>
#       <td>0.253055</td>
#       <td>0.081053</td>
#       <td>0.918947</td>
#       <td>0.918947</td>
#       <td>0.918947</td>
#       <td>0.918947</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.517450</td>
#       <td>0.205732</td>
#       <td>0.071579</td>
#       <td>0.928421</td>
#       <td>0.928421</td>
#       <td>0.928421</td>
#       <td>0.928421</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.365549</td>
#       <td>0.196749</td>
#       <td>0.061053</td>
#       <td>0.938947</td>
#       <td>0.938947</td>
#       <td>0.938947</td>
#       <td>0.938947</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')
# Out:
# Path('models/stage-1.pth')

# %%
print("Accuracy: ", 1-float(learn.recorder.metrics[0].value))
# Out:
# Accuracy:  0.9389473684132099

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=3.0199516913853586e-05)

# %%
learn.fit_one_cycle(10, lr_max = 3.0199516913853586e-05)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.291472</td>
#       <td>0.188054</td>
#       <td>0.057895</td>
#       <td>0.942105</td>
#       <td>0.942105</td>
#       <td>0.942105</td>
#       <td>0.942105</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.257222</td>
#       <td>0.174968</td>
#       <td>0.053684</td>
#       <td>0.946316</td>
#       <td>0.946316</td>
#       <td>0.946316</td>
#       <td>0.946316</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.212788</td>
#       <td>0.160692</td>
#       <td>0.048421</td>
#       <td>0.951579</td>
#       <td>0.951579</td>
#       <td>0.951579</td>
#       <td>0.951579</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.176849</td>
#       <td>0.147590</td>
#       <td>0.051579</td>
#       <td>0.948421</td>
#       <td>0.948421</td>
#       <td>0.948421</td>
#       <td>0.948421</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.135923</td>
#       <td>0.150050</td>
#       <td>0.051579</td>
#       <td>0.948421</td>
#       <td>0.948421</td>
#       <td>0.948421</td>
#       <td>0.948421</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.102702</td>
#       <td>0.129095</td>
#       <td>0.045263</td>
#       <td>0.954737</td>
#       <td>0.954737</td>
#       <td>0.954737</td>
#       <td>0.954737</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.089691</td>
#       <td>0.121884</td>
#       <td>0.041053</td>
#       <td>0.958947</td>
#       <td>0.958947</td>
#       <td>0.958947</td>
#       <td>0.958947</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.076571</td>
#       <td>0.141220</td>
#       <td>0.045263</td>
#       <td>0.954737</td>
#       <td>0.954737</td>
#       <td>0.954737</td>
#       <td>0.954737</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.064803</td>
#       <td>0.124619</td>
#       <td>0.040000</td>
#       <td>0.960000</td>
#       <td>0.960000</td>
#       <td>0.960000</td>
#       <td>0.960000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.056177</td>
#       <td>0.123948</td>
#       <td>0.037895</td>
#       <td>0.962105</td>
#       <td>0.962105</td>
#       <td>0.962105</td>
#       <td>0.962105</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')
# Out:
# Path('models/stage-2.pth')

# %%
print("Accuracy: ", 1-float(learn.recorder.metrics[0].value))
# Out:
# Accuracy:  0.9621052630245686

# %%
interpretation = ClassificationInterpretation.from_learner(learn)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interpretation.plot_top_losses(9, figsize=(15,11))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.show_results(figsize=(12,8))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(16,12))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# testing

# %%
test_loader = train_dls.test_dl(test_fns) 
test_pred, y = learn.get_preds(dl=test_loader)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
test_pred
# Out:
# tensor([[4.0480e-08, 4.1306e-10, 5.8717e-09,  ..., 1.5832e-10, 5.3750e-09,
#          1.3234e-07],
#         [1.0568e-09, 1.0866e-06, 2.1220e-07,  ..., 8.6933e-10, 6.4856e-10,
#          9.9998e-01],
#         [2.6514e-05, 2.5300e-05, 6.3844e-06,  ..., 3.8396e-04, 9.9929e-01,
#          2.4642e-05],
#         ...,
#         [5.2862e-06, 1.8849e-06, 6.6004e-07,  ..., 1.3149e-11, 1.2186e-10,
#          2.6016e-06],
#         [3.5539e-07, 9.9957e-01, 2.7471e-05,  ..., 4.6899e-07, 3.1133e-04,
#          1.9210e-07],
#         [1.4003e-02, 3.0215e-05, 2.3730e-04,  ..., 5.2055e-05, 6.2240e-05,
#          2.8372e-04]])

# %%
pred_labels = torch.argmax(test_pred, dim=1)
pred_labels[1:10]
# Out:
# tensor([11, 10, 11,  6,  3, 11,  5, 11,  6])

# %%
vocab = {key: val for key, val in enumerate(train_dls.vocab)}
vocab
# Out:
# {0: 'Black-grass',
#  1: 'Charlock',
#  2: 'Cleavers',
#  3: 'Common Chickweed',
#  4: 'Common wheat',
#  5: 'Fat Hen',
#  6: 'Loose Silky-bent',
#  7: 'Maize',
#  8: 'Scentless Mayweed',
#  9: 'Shepherds Purse',
#  10: 'Small-flowered Cranesbill',
#  11: 'Sugar beet'}

# %%
predicted_labels = []
for i in pred_labels:
    predicted_labels.append(vocab[i.float().item()])

# %%
predicted_labels[1:10]
# Out:
# ['Sugar beet',
#  'Small-flowered Cranesbill',
#  'Sugar beet',
#  'Loose Silky-bent',
#  'Common Chickweed',
#  'Sugar beet',
#  'Fat Hen',
#  'Sugar beet',
#  'Loose Silky-bent']

# %%
test_files = []
for i in test_fns:
    print(i.name)
    test_files.append(i.name)
# Out:
# d7017f701.png
# 6680836dd.png
# a0b393945.png
# e783f5a4f.png
# d93c7ab6d.png
# df7cb5f87.png
# 24c94a6ca.png
# 444473900.png
# 9baf94467.png
# 3f92d8039.png
# d84d37a61.png
# 4f44ca525.png
# b7a7f6390.png
# 1d0cbd819.png
# ec08a5d56.png
# 3da774107.png
# 8e6ec1ca6.png
# 8e4eaeec0.png
# 03ef36742.png
# 1f5e5554e.png
# 78750e0ff.png
# e471f1d3a.png
# 809eb0b82.png
# 8916793ce.png
# c06e7c748.png
# 1b490196c.png
# b6a3f7876.png
# 04814f36d.png
# 0d31e6602.png
# a8da9c08d.png
# 1c52ea820.png
# 55fed435f.png
# cfd8165e9.png
# 17529c555.png
# aaf4da98f.png
# 8b27bfd2b.png
# 2d5058a59.png
# 5bdcfa329.png
# a006a475c.png
# f4ad9d950.png
# 37c3108d6.png
# 0caeda5df.png
# 86f08e6d1.png
# 9d3cb4745.png
# e73e308be.png
# d2f0f326e.png
# f9f35cbd4.png
# c7b07431e.png
# 6dd095129.png
# d17f48d3b.png
# 2f0004a7f.png
# c26ccf73c.png
# 728eabae1.png
# 3e9f41817.png
# 00c47e980.png
# 2dd5cfba9.png
# 19b51843a.png
# f48916a8c.png
# 13b9fa92d.png
# b39c71707.png
# b1cd2a91e.png
# c2de6020a.png
# efe19dc32.png
# 1c680883c.png
# bb1d1bfd3.png
# 9fab816f2.png
# 1d56351b2.png
# acdb75e00.png
# f25996db8.png
# 0dba99002.png
# ce3d280eb.png
# ab35453cb.png
# 92292055d.png
# 7d4cd07ad.png
# a85fc8c9a.png
# 4bcdaa5e2.png
# f85ed9b6d.png
# 29f49cd0b.png
# f9b6bfb00.png
# 071cb3ece.png
# 8cf2e3e6c.png
# b130a0632.png
# 800a8c17e.png
# e15472085.png
# 593896f83.png
# cf3a8b2fd.png
# 239bdf640.png
# 1821eb11a.png
# dc55449b2.png
# 87608f7aa.png
# c7051c902.png
# 7beb2766f.png
# 711b46fba.png
# 0ad9e7dfb.png
# 8874bba69.png
# cc74feadc.png
# 3d38a87bc.png
# 659412b1a.png
# 976e4e079.png
# e3f50adfc.png
# fe9e87b78.png
# 8301b0547.png
# 4e69d100a.png
# 59f62ad1d.png
# 063363305.png
# 9326bda1b.png
# abf8b0772.png
# 089ad62a7.png
# e4d5ec761.png
# a2d25b4f3.png
# 5a38ac566.png
# 20e562fd5.png
# 085974290.png
# 65e97117e.png
# 4c5ab9b68.png
# 279df95f2.png
# 3eebd36c6.png
# 7b21ba6ba.png
# a935ca110.png
# 5ca0205f9.png
# 16fd2e01a.png
# d2fd9df40.png
# 22e79540f.png
# 80e299ae9.png
# 8cf909eb3.png
# fbf88b6be.png
# 37714071b.png
# 589e643b8.png
# d0cdc768f.png
# 31fcdc161.png
# c35efa095.png
# 8ab8a958b.png
# 969a851be.png
# 0437393b1.png
# 9643fc5f4.png
# 20817c846.png
# 9c777333d.png
# 32a8c8a1d.png
# 653193c1a.png
# 33748968f.png
# cae684f8f.png
# c069fc3fa.png
# dc4cd56a3.png
# b9062c1c8.png
# e921021a8.png
# 721be0a4a.png
# fe29629fb.png
# 59b2c6f2b.png
# 25a4c427e.png
# 97844bfd5.png
# ef74dbcad.png
# cb76a7766.png
# dd5ec63d9.png
# 29bab7cad.png
# 0625f063b.png
# 56a01b835.png
# d41d87796.png
# a3b375b34.png
# ae90f2827.png
# 466bb6d3b.png
# 24a058589.png
# e0ec5b6a1.png
# 9b9911f20.png
# 003d61042.png
# 55920f07f.png
# d89db156f.png
# f8318faf1.png
# 61dd2cdc5.png
# f445fe6fb.png
# e5368474f.png
# c0f5d9ac8.png
# 4392d93cf.png
# c60e91e07.png
# e52493d0b.png
# 1fefb54b7.png
# 20f983a71.png
# fea3da57c.png
# 558aa7deb.png
# 4287d810c.png
# b687160f5.png
# abc331628.png
# fd87b36ae.png
# a85b48a95.png
# 007b3da8b.png
# 205df1df3.png
# 5a6bf96f6.png
# 25fa8d109.png
# 116b136de.png
# 521b27a17.png
# 24dbc3b21.png
# 67ce3eaa6.png
# 76dbd1054.png
# f2dc546ca.png
# 2d992d1fb.png
# fc6f686fb.png
# 65d08b894.png
# afcf6abd5.png
# a060c1cf8.png
# 5779fe8b4.png
# 5b3beec58.png
# 4bbfd1e05.png
# 5b63dcc21.png
# b7192c70f.png
# fd253a74e.png
# 0885e7690.png
# 0fb233ad6.png
# bfab3e3d0.png
# 958bb9e96.png
# 756dd5070.png
# e84464f5a.png
# 6df8e31ea.png
# 3edf5e9ef.png
# 7d22abf91.png
# c64370a72.png
# 8d6acbe9b.png
# 00ef713a8.png
# 3185294c8.png
# 122913909.png
# 7f31c7f42.png
# 7e9cf1c46.png
# a169b71e7.png
# ad12382d4.png
# d6d31dcbe.png
# 1694a70e4.png
# 177d7e2a4.png
# 85431c075.png
# 78b1bf91a.png
# c7ae30f3a.png
# 6a41bf95b.png
# 0c5f6c493.png
# 406ecb5c5.png
# 3d67c434b.png
# 9c8b08a24.png
# df521c0c0.png
# 1f290e016.png
# 099b961ec.png
# 01291174f.png
# 675ec1b0b.png
# 4e18ab737.png
# 55251925f.png
# 8170d33c1.png
# d3331e071.png
# 39858776a.png
# 6b721f68e.png
# e88bf0db9.png
# f593c9cf0.png
# e5297b675.png
# 26852751a.png
# 5bd71f445.png
# 647689543.png
# 241e6935a.png
# c63da993b.png
# 824f5d4e5.png
# 8e2e5604e.png
# ef7a5651d.png
# e6f1211a2.png
# 126a71ce0.png
# 41e07778c.png
# 36839d5e9.png
# 35cf9fa01.png
# 7fdb7202d.png
# a38b8a581.png
# 258b1183c.png
# 0c4199daa.png
# 2df78338c.png
# 19e58cc5e.png
# 592473c83.png
# a9d2eab61.png
# 8bc0261c9.png
# fef2ade8c.png
# 86676d627.png
# 35ebe165c.png
# bb20fce02.png
# 88ac6df54.png
# 90d119d25.png
# 33317fc2a.png
# c5e88cd42.png
# 39b740f7e.png
# 754b1adf8.png
# e7077322d.png
# 4bbf1f6ea.png
# 4c7838de4.png
# 61b044411.png
# 3abb502fb.png
# b62dca166.png
# dd9f36df7.png
# 69d1669f8.png
# 5817b766d.png
# 7b52585da.png
# 73260a4ee.png
# ede6b84b4.png
# d01873fdd.png
# 963544aa0.png
# 1364b297a.png
# 8303b27ed.png
# 63c07d340.png
# 8b9144917.png
# 1e095a7e1.png
# 6be169e41.png
# e96e57a90.png
# 780bd2a2c.png
# 98da6ef4e.png
# 4f83143e1.png
# 026716f9b.png
# 523e5505c.png
# 446f7da01.png
# 98d819587.png
# 6908fb540.png
# c5078bac5.png
# 2f246d688.png
# e4a76885b.png
# 26e7ae885.png
# 24d36c52c.png
# 0f6cbe5e8.png
# 48d97c645.png
# b47691c08.png
# 855955aaf.png
# 785a73ab8.png
# f4e7733d4.png
# 615d2b0a9.png
# cadab6616.png
# e901b0f28.png
# 74fd477eb.png
# da4ed3a28.png
# 1623fb9e1.png
# 37297a64c.png
# 288564c76.png
# c88ebfb47.png
# 93d76fd5d.png
# 808578ed5.png
# 5bc6595f6.png
# 043449b0b.png
# 99036c51d.png
# 2e86f1085.png
# 897e5a8de.png
# 8ca6140ca.png
# bb64660b7.png
# ac3193f78.png
# 6d6eb3830.png
# 3a909ead8.png
# 67e185673.png
# 974959ec1.png
# 115f93ecc.png
# 8311740de.png
# cd6adba97.png
# 5dcad9a53.png
# 32b42c120.png
# 5c3cd7ea2.png
# bf3924a57.png
# 50de8a115.png
# 12625488b.png
# 4b032563b.png
# a0f37c726.png
# 7f46a71db.png
# 6982a9d30.png
# c74c5b7fc.png
# 4a337a4a9.png
# 0c45ace27.png
# c6c8d4ba0.png
# 00d090cde.png
# 686dc7ec8.png
# 6c874918c.png
# c50335991.png
# dce2f6612.png
# 550a8b7e6.png
# f1f7c833f.png
# e19673dc9.png
# d2f422ccb.png
# ef9676433.png
# 77ccb8b2a.png
# b341d0aab.png
# 599c82eea.png
# b215531dd.png
# 5eb9c26a6.png
# 8a32d0bfa.png
# ef65533d5.png
# df11d56a7.png
# 429211ee6.png
# 9c0c5b731.png
# 9aa5587fe.png
# b31292706.png
# fea1d13d6.png
# fb022edf9.png
# 55a852f40.png
# 60fea2ef6.png
# 3d65168c2.png
# 1459e96a0.png
# 56112b92c.png
# aa7d098d1.png
# 8cfd98117.png
# 1376f3b63.png
# f6d250856.png
# bb7621cb3.png
# 1758a1baf.png
# 9cce7328c.png
# 02cfeb38d.png
# a276c65f7.png
# dcd7ff249.png
# 0bf7bfb05.png
# 7506c0c02.png
# 79d93bc96.png
# 599691cd9.png
# 4e1190d78.png
# f33e9d918.png
# b4f7c9214.png
# 23bc8ec4f.png
# b145ba9d4.png
# 8104422bb.png
# 7696badea.png
# 93079d970.png
# 948cdb277.png
# e721c6ac8.png
# 35a90f8d0.png
# a2b703e21.png
# fdea6b119.png
# 0ae6668fa.png
# 16467a950.png
# eaf0815e2.png
# 8455169fe.png
# cb496f36e.png
# 3dd52bd2a.png
# 4049a6ea6.png
# 32c86784b.png
# 9d79a1f0c.png
# 19618ad6a.png
# a74bf916d.png
# adb7a032c.png
# 39c8fde99.png
# 1b6a6494d.png
# 2bd74d2da.png
# be341dbdc.png
# 3ebbe9ca4.png
# e1809cef2.png
# cd5f0db1c.png
# da713c465.png
# 770a265f5.png
# 6da892be6.png
# 05341a8a6.png
# a5db42f7d.png
# c0d9e170b.png
# 1191ba346.png
# 835dc5447.png
# a93f940d6.png
# aad8375e0.png
# d102e1a15.png
# 8db450ce3.png
# 0ee4ad224.png
# b944a49ca.png
# 6b9d6f8c9.png
# fd925f542.png
# d563be369.png
# 248436078.png
# dabe3e5be.png
# a8b431a3e.png
# 699d3c707.png
# 3eda9cbb6.png
# 1d48b7564.png
# c6b76307d.png
# afa446484.png
# f9ea23fb5.png
# 966ae5ad9.png
# 8f523520c.png
# d09d24c58.png
# c10ccbd82.png
# b0acaff4a.png
# e5e3dccff.png
# f3fcfff1b.png
# 219fd68d5.png
# b3e08b037.png
# e5881dd33.png
# c0461776c.png
# 3281183f9.png
# 165681fd9.png
# 590f5aea6.png
# e98e5d1d5.png
# 3b73c3b61.png
# 22fbf13d6.png
# 47b7d8e17.png
# e478c452c.png
# 52a87abe5.png
# bb1c84bbc.png
# 3827436f3.png
# aee6fa3df.png
# c8f50f0c3.png
# cbba27d89.png
# bebcaab66.png
# 060450d79.png
# b7ad92859.png
# 8ece6efec.png
# f4021df6c.png
# 24d78df74.png
# 8faadb6a8.png
# 9df3275da.png
# 721b2c47a.png
# e5064f6be.png
# 7c85b0265.png
# 71f5323c5.png
# e80a259c5.png
# c5e419015.png
# b2706e2b3.png
# 592cc5b89.png
# 66ab0e8d0.png
# f66ae4070.png
# 71b232519.png
# d5f7dd60a.png
# 6bce55e05.png
# 78c5fba1d.png
# 2406d6c99.png
# 827279bad.png
# 1dc7c45df.png
# bffc08672.png
# 5ca2687a4.png
# ce42adffb.png
# 2126dc71b.png
# 46c14fde2.png
# da9ef7858.png
# 148bbda66.png
# 7615e52d3.png
# b573b7a56.png
# 30ad31220.png
# ba3ce6b3e.png
# 31f3dd81f.png
# 502dff972.png
# b30ab4659.png
# 604dd663f.png
# 37e545a60.png
# 59358cd44.png
# da231c97f.png
# a8388a37f.png
# 42e7ed442.png
# 64fe8beb9.png
# e14afa235.png
# 851c90831.png
# 96f14d90c.png
# 79dafec17.png
# cbe761896.png
# 3f64c2c1b.png
# caa2fbd79.png
# 11d3f68ff.png
# bdde957ec.png
# 4b155fb07.png
# 59c6a9f95.png
# 8a30b2de3.png
# a7bd7cadb.png
# 7cabd68cc.png
# 8a8d6c712.png
# a800caead.png
# fda0b5c38.png
# 338c7e907.png
# 65489944f.png
# fc3e58836.png
# 377283a21.png
# 1bf9b94a6.png
# 7f9e9565d.png
# 0c51bf229.png
# eec1079a1.png
# 07e62f903.png
# 2ea664465.png
# 8c98a6e9b.png
# 03a2ee656.png
# 08d591441.png
# 54c8bb900.png
# a1e0a6c02.png
# de0b79659.png
# 33448fe39.png
# cf46d09c5.png
# bf66b9cd2.png
# 391dcd7fd.png
# 47f9e5d91.png
# 79fba50db.png
# 38c054379.png
# 48ef6a2ff.png
# ce15eee52.png
# ef02b4ee7.png
# 87f627bf9.png
# 187668bde.png
# b98327bf4.png
# a254d71f6.png
# d0152bd7c.png
# d668409ff.png
# 9a3f20121.png
# a2c89c367.png
# 3fbd0fc6a.png
# 0086a6340.png
# 3f826b318.png
# 97b2f0a10.png
# b03397525.png
# d14aa43f3.png
# e15fce4f2.png
# 20ea96bcc.png
# 866be78b0.png
# cec5bf198.png
# 456d507c0.png
# 2b55a2da2.png
# e19ad6ac9.png
# 5e6a237f2.png
# 8b043093d.png
# 5f04aed97.png
# cc3d2a59a.png
# 6ba4ef411.png
# 14bb43eee.png
# 410e6f702.png
# d515398fd.png
# 4c8005bbc.png
# 539961189.png
# 0d117d910.png
# 71334c634.png
# b828443ff.png
# a83820a2c.png
# d6d80a321.png
# 9c32a797e.png
# b29339405.png
# e9cd91682.png
# 5315c2dca.png
# 75cb95e91.png
# 29ce426a1.png
# edfdb4aeb.png
# 780defa2e.png
# 36d62bf36.png
# a4b61a4ea.png
# 03e322a29.png
# 65e262a6d.png
# 7691014a1.png
# 5bbc0a255.png
# aecfaed64.png
# 3efa1f66c.png
# fea355851.png
# c1ecff98b.png
# 4ac29bbf0.png
# 86c309150.png
# ef3e232ad.png
# a35fd6fbb.png
# ace8761dd.png
# 98062cd87.png
# 534e74d83.png
# 953496deb.png
# 74068643d.png
# 99569b224.png
# 2ff5cb348.png
# 0e8492cb1.png
# dabea05f4.png
# 19fdf19fb.png
# 1cfd91582.png
# bea23d9f8.png
# d350a25fa.png
# 34dd57ca9.png
# ac75d3326.png
# 618de3d7a.png
# 59e1cea8d.png
# 4ea7493d5.png
# 41f1c3cdb.png
# 856f2910a.png
# 664194d19.png
# 486e59179.png
# f4234cf4f.png
# 8585f9718.png
# a1da8be3c.png
# 837ac0270.png
# 0ebf8f2f4.png
# 7a38416be.png
# 52dc7a4d6.png
# e82017baa.png
# a3d0031fd.png
# 06d12f6fa.png
# 172f9b10b.png
# 995c7ab1e.png
# 25cf6eb73.png
# c832e4302.png
# 03566743d.png
# cfb18d262.png
# d6c8c3c48.png
# 90b595f12.png
# 1d321253f.png
# 406162ef9.png
# 16357b436.png
# d8f4923f8.png
# 53e6e9000.png
# 8e3ed0a25.png
# 5af1d74ee.png
# be2499cf4.png
# 82b5f4d33.png
# 5b3000b9a.png
# fba8fc78a.png
# da5255450.png
# b4c3df835.png
# dfb1d9012.png
# e1a0e3202.png
# beebe5f4e.png
# 892e9d6c6.png
# 752101fdf.png
# ff65bc002.png
# 223e4af09.png
# 5883b423d.png
# d689256be.png
# 1926e82fd.png
# a8de7c1b7.png
# bd72d4d8a.png
# 2693e5c65.png
# 0c27cf05f.png
# 1541bdb2e.png
# a55d26a4c.png
# b6f3d8b5d.png
# 76555b064.png
# e1abb4ff9.png
# 48231e475.png
# 74d810f87.png
# c85ef220d.png
# 632156793.png
# b5c7fd009.png
# c0bc3997b.png
# 4e9d3765f.png
# c75a82234.png
# 270b939cf.png
# a19c3faca.png
# a544fc46d.png
# 36ed4f215.png
# 60f0bc617.png
# 1be0713da.png
# 8c9953903.png
# 6edb96d45.png
# 060f1dc84.png
# a8c8a1db0.png
# 606647f64.png
# 88d8a4508.png
# f4caf74f9.png
# 862b8e7a0.png
# c7eb96871.png
# b3d6fdb80.png
# fa9f3a8f9.png
# f351ce097.png
# 2d9c798f9.png
# 44e8b8833.png
# 0021e90e4.png
# 17a78fb44.png
# 8d6991365.png
# 490c4f9c8.png
# 71e73a8a0.png
# 1f3f44563.png
# 43ede9de9.png
# f1e87cba7.png
# 23e480e64.png
# 7d3045fc3.png
# ab0f67743.png
# 0911d3dee.png
# fa5fd1384.png
# c10db7ae2.png
# bd789d151.png
# 2a667e099.png
# b026bf8ca.png
# 5ee9d0a5b.png
# a890ac088.png
# c4ed8ed38.png
# ffc6f8527.png
# d9c50616e.png
# 3526b05cc.png
# 6a47821f9.png
# cf90fc52d.png
# a74d475c2.png
# 1312065a5.png
# af45e222a.png
# 39d569be4.png
# fda39e16f.png
# 6edc76e7c.png
# 53ceb4657.png
# fadc6adbc.png
# e9d48d664.png
# 2a5064f19.png
# 6db684fff.png
# 8a4d3a1b1.png
# 3bbef3ecb.png
# 808cf55c6.png
# 6049234e6.png
# 9b4800b42.png
# f0ffa00bd.png
# 96ecad7a1.png
# 668c1007c.png
# eef131644.png
# 3fbf1a417.png
# 9516e56c4.png
# 79e5ea8fa.png
# 5296835a0.png
# 91e469b4a.png
# 0751c0bbc.png
# d09275360.png
# f23faf9c1.png
# 54b3afd58.png
# 506347cfe.png
# 60ee66ddd.png
# 17d5e5ac4.png
# 8e29abce1.png
# 0a64e3e6c.png
# d488a4fe1.png
# 8dbb8e1b9.png
# 4823c3ffa.png
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 3
#       1 test_files = []
#       2 for i in test_fns:
# ----> 3     print(i.name)
#       4     test_files.append(i.name)
#
# AttributeError: 'str' object has no attribute 'name'

# %%
test_files[1:5]
# Out:
# ['6680836dd.png', 'a0b393945.png', 'e783f5a4f.png', 'd93c7ab6d.png']

# %%
csv_file =  pd.DataFrame({'file': test_files,'species': predicted_labels})
csv_file.to_csv('labels.csv',index=False)

# %%
# figure out how to see the accuracy

# %%
accuracy = accuracy(test_pred, y)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 accuracy = accuracy(test_pred, y)
#       2 print(f'Accuracy: {accuracy:.4f}')
#
# File ~/miniconda/lib/python3.11/site-packages/fastai/metrics.py:105, in accuracy(inp, targ, axis)
#     103 def accuracy(inp, targ, axis=-1):
#     104     "Compute accuracy with `targ` when `pred` is bs * n_classes"
# --> 105     pred,targ = flatten_check(inp.argmax(dim=axis), targ)
#     106     return (pred == targ).float().mean()
#
# File ~/miniconda/lib/python3.11/site-packages/fastai/torch_core.py:786, in flatten_check(inp, targ)
#     784 def flatten_check(inp, targ):
#     785     "Check that `inp` and `targ` have the same number of elements and flatten them."
# --> 786     inp,targ = TensorBase(inp.contiguous()).view(-1),TensorBase(targ.contiguous()).view(-1)
#     787     test_eq(len(inp), len(targ))
#     788     return inp,targ
#
# AttributeError: 'NoneType' object has no attribute 'contiguous'
